# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | waipawa
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | birin
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | rocha
# Processing Record 12 of Set 1 | kysyl-syr
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | verkhoyansk
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | freeport
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | puerto escondido
# Processing Record 20 of Set 1 | vysokogornyy
# Processing Record 21 of Set 1 | japura
# Processing Record 22 of Set 1 | marystown
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | hambantota
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | ostrowiec swietokrzyski
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | ixtapa
# Processing Record 33 of Set 1 | khandyga
# Processing Record 34 of Set 1 | westport
# Processing Record 35 of Set 1 | ornskoldsvik
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | koungou
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | fare
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | lata
# Processing Record 1 of Set 2 | wexford
# Processing Record 2 of Set 2 | nicoya
# Processing Record 3 of Set 2 | baraki barak
# Processing Record 4 of Set 2 | faya
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | beringovskiy
# Processing Record 7 of Set 2 | rudbar
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | ochamchira
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | kamenskiy
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | antofagasta
# Processing Record 14 of Set 2 | sitka
# Processing Record 15 of Set 2 | vostok
# Processing Record 16 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | brae
# Processing Record 19 of Set 2 | maturin
# Processing Record 20 of Set 2 | hayden
# Processing Record 21 of Set 2 | sorland
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | hofn
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | jumla
# Processing Record 26 of Set 2 | eureka
# Processing Record 27 of Set 2 | tomar do geru
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | la orilla
# Processing Record 30 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 2 | diamantino
# Processing Record 32 of Set 2 | uzyn
# Processing Record 33 of Set 2 | santiago del estero
# Processing Record 34 of Set 2 | oda
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | aksu
# Processing Record 37 of Set 2 | catamarca
# Processing Record 38 of Set 2 | annan
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | vieux fort
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | naifaru
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | vila franca do campo
# Processing Record 47 of Set 2 | vasterhaninge
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | college
# Processing Record 50 of Set 2 | eenhana
# Processing Record 1 of Set 3 | erenhot
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | poronaysk
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | biu
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | ketchikan
# Processing Record 13 of Set 3 | mananjary
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | tolaga bay
# Processing Record 17 of Set 3 | kibala
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | skjervoy
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | lusaka
# Processing Record 25 of Set 3 | hongjiang
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | kindersley
# Processing Record 29 of Set 3 | newport
# Processing Record 30 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | severo-yeniseyskiy
# Processing Record 36 of Set 3 | batsfjord
# Processing Record 37 of Set 3 | nsanje
# Processing Record 38 of Set 3 | roald
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | mumford
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | san ramon
# Processing Record 43 of Set 3 | lubao
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | dzhebariki-khaya
# Processing Record 47 of Set 3 | san quintin
# Processing Record 48 of Set 3 | mayo
# Processing Record 49 of Set 3 | tatawin
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | pisco
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | sisimiut
# Processing Record 8 of Set 4 | stromness
# Processing Record 9 of Set 4 | ostrovnoy
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | totness
# Processing Record 12 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 4 | hermanus
# Processing Record 14 of Set 4 | touros
# Processing Record 15 of Set 4 | broken hill
# Processing Record 16 of Set 4 | mandalgovi
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | kampong thum
# Processing Record 19 of Set 4 | srandakan
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | almaznyy
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | hobart
# Processing Record 24 of Set 4 | porto novo
# Processing Record 25 of Set 4 | seoul
# Processing Record 26 of Set 4 | sanjwal
# Processing Record 27 of Set 4 | dzheguta
# Processing Record 28 of Set 4 | alofi
# Processing Record 29 of Set 4 | karratha
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | atasu
# Processing Record 32 of Set 4 | kalmunai
# Processing Record 33 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | praya
# Processing Record 36 of Set 4 | sioux lookout
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | rio grande
# Processing Record 40 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 4 | skalnyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 4 | itupiranga
# Processing Record 44 of Set 4 | alice springs
# Processing Record 45 of Set 4 | vardo
# Processing Record 46 of Set 4 | mount pleasant
# Processing Record 47 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 4 | oranjestad
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 1 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | cody
# Processing Record 5 of Set 5 | chipinge
# Processing Record 6 of Set 5 | ukiah
# Processing Record 7 of Set 5 | cienfuegos
# Processing Record 8 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 5 | prince rupert
# Processing Record 10 of Set 5 | bay roberts
# Processing Record 11 of Set 5 | pierre
# Processing Record 12 of Set 5 | sinnamary
# Processing Record 13 of Set 5 | zhigansk
# Processing Record 14 of Set 5 | solnechnyy
# Processing Record 15 of Set 5 | jining
# Processing Record 16 of Set 5 | onega
# Processing Record 17 of Set 5 | evensk
# Processing Record 18 of Set 5 | matagami
# Processing Record 19 of Set 5 | wewak
# Processing Record 20 of Set 5 | tshikapa
# Processing Record 21 of Set 5 | oktyabrskiy
# Processing Record 22 of Set 5 | beloha
# Processing Record 23 of Set 5 | jaguey grande
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | asyut
# Processing Record 26 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | chimore
# Processing Record 28 of Set 5 | mosquera
# Processing Record 29 of Set 5 | baganga
# Processing Record 30 of Set 5 | taraz
# Processing Record 31 of Set 5 | moose factory
# Processing Record 32 of Set 5 | zavitinsk
# Processing Record 33 of Set 5 | palmer
# Processing Record 34 of Set 5 | mazamari
# Processing Record 35 of Set 5 | rawtenstall
# Processing Record 36 of Set 5 | caravelas
# Processing Record 37 of Set 5 | panguipulli
# Processing Record 38 of Set 5 | acapulco
# Processing Record 39 of Set 5 | hobyo
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | dikson
# Processing Record 42 of Set 5 | byron bay
# Processing Record 43 of Set 5 | georgiyevskaya
# Processing Record 44 of Set 5 | bereda
# Processing Record 45 of Set 5 | lovozero
# Processing Record 46 of Set 5 | yenagoa
# Processing Record 47 of Set 5 | suntar
# Processing Record 48 of Set 5 | gradinari
# Processing Record 49 of Set 5 | mehnagar
# Processing Record 50 of Set 5 | nipawin
# Processing Record 1 of Set 6 | flin flon
# Processing Record 2 of Set 6 | dinar
# Processing Record 3 of Set 6 | mersin
# Processing Record 4 of Set 6 | broome
# Processing Record 5 of Set 6 | kaitangata
# Processing Record 6 of Set 6 | wanning
# Processing Record 7 of Set 6 | mangrol
# Processing Record 8 of Set 6 | waldoboro
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | lasa
# Processing Record 11 of Set 6 | ust-tsilma
# Processing Record 12 of Set 6 | chihuahua
# Processing Record 13 of Set 6 | sokolka
# Processing Record 14 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 6 | vredendal
# Processing Record 16 of Set 6 | auki
# Processing Record 17 of Set 6 | husavik
# Processing Record 18 of Set 6 | lucea
# Processing Record 19 of Set 6 | baruun-urt
# Processing Record 20 of Set 6 | kismayo
# Processing Record 21 of Set 6 | sweetwater
# Processing Record 22 of Set 6 | halifax
# Processing Record 23 of Set 6 | usogorsk
# Processing Record 24 of Set 6 | tasiilaq
# Processing Record 25 of Set 6 | santa cruz
# Processing Record 26 of Set 6 | villarrica
# Processing Record 27 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 28 of Set 6 | moana
# Processing Record 29 of Set 6 | omsukchan
# Processing Record 30 of Set 6 | moses lake
# Processing Record 31 of Set 6 | puerto madryn
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | ucluelet
# Processing Record 34 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | manoel urbano
# Processing Record 37 of Set 6 | bilma
# Processing Record 38 of Set 6 | la palma
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | katsina
# Processing Record 41 of Set 6 | ballina
# Processing Record 42 of Set 6 | norman wells
# Processing Record 43 of Set 6 | itarema
# Processing Record 44 of Set 6 | strezhevoy
# Processing Record 45 of Set 6 | sobolevo
# Processing Record 46 of Set 6 | horsham
# Processing Record 47 of Set 6 | okakarara
# Processing Record 48 of Set 6 | saint george
# Processing Record 49 of Set 6 | chumikan
# Processing Record 50 of Set 6 | calvinia
# Processing Record 1 of Set 7 | kautokeino
# Processing Record 2 of Set 7 | mrakovo
# Processing Record 3 of Set 7 | lazdijai
# Processing Record 4 of Set 7 | gornopravdinsk
# Processing Record 5 of Set 7 | yashkino
# Processing Record 6 of Set 7 | namatanai
# Processing Record 7 of Set 7 | sochi
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | belmonte
# Processing Record 10 of Set 7 | abbeville
# Processing Record 11 of Set 7 | bailieborough
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | ushtobe
# Processing Record 14 of Set 7 | mabaruma
# Processing Record 15 of Set 7 | kruisfontein
# Processing Record 16 of Set 7 | gigmoto
# Processing Record 17 of Set 7 | kaseda
# Processing Record 18 of Set 7 | valle de allende
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | bambous virieux
# Processing Record 23 of Set 7 | bomet
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | meylan
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | luwingu
# Processing Record 28 of Set 7 | mayaguez
# Processing Record 29 of Set 7 | menongue
# Processing Record 30 of Set 7 | burica
# City not found. Skipping...
# Processing Record 31 of Set 7 | georgetown
# Processing Record 32 of Set 7 | benavente
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | neuquen
# Processing Record 35 of Set 7 | tiarei
# Processing Record 36 of Set 7 | gurjaani
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | agadir
# Processing Record 39 of Set 7 | fort-shevchenko
# Processing Record 40 of Set 7 | port alfred
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 43 of Set 7 | urengoy
# Processing Record 44 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 45 of Set 7 | puerto narino
# Processing Record 46 of Set 7 | ozernovskiy
# Processing Record 47 of Set 7 | leningradskiy
# Processing Record 48 of Set 7 | lixourion
# Processing Record 49 of Set 7 | bara
# Processing Record 50 of Set 7 | meadow lake
# Processing Record 1 of Set 8 | fortuna
# Processing Record 2 of Set 8 | cabo san lucas
# Processing Record 3 of Set 8 | ler
# Processing Record 4 of Set 8 | kostino
# Processing Record 5 of Set 8 | banda aceh
# Processing Record 6 of Set 8 | valera
# Processing Record 7 of Set 8 | batagay
# Processing Record 8 of Set 8 | corning
# Processing Record 9 of Set 8 | saldanha
# Processing Record 10 of Set 8 | aksarka
# Processing Record 11 of Set 8 | chicama
# Processing Record 12 of Set 8 | lazaro cardenas
# Processing Record 13 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | glace bay
# Processing Record 15 of Set 8 | ulladulla
# Processing Record 16 of Set 8 | adrar
# Processing Record 17 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 8 | inuvik
# Processing Record 19 of Set 8 | arauco
# Processing Record 20 of Set 8 | sidney
# Processing Record 21 of Set 8 | soubre
# Processing Record 22 of Set 8 | puerto penasco
# Processing Record 23 of Set 8 | north platte
# Processing Record 24 of Set 8 | nemuro
# Processing Record 25 of Set 8 | fuerte olimpo
# Processing Record 26 of Set 8 | pustoshka
# Processing Record 27 of Set 8 | sindor
# Processing Record 28 of Set 8 | bonito
# Processing Record 29 of Set 8 | lishui
# Processing Record 30 of Set 8 | abu dhabi
# Processing Record 31 of Set 8 | simbahan
# Processing Record 32 of Set 8 | ivanava
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | nerja
# Processing Record 36 of Set 8 | clyde river
# Processing Record 37 of Set 8 | tudela
# Processing Record 38 of Set 8 | ereymentau
# Processing Record 39 of Set 8 | cermik
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | warwick
# Processing Record 42 of Set 8 | mizunami
# Processing Record 43 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 8 | jiayuguan
# Processing Record 45 of Set 8 | brodokalmak
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | jalu
# Processing Record 48 of Set 8 | springbok
# Processing Record 49 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 8 | flinders
# Processing Record 1 of Set 9 | bintulu
# Processing Record 2 of Set 9 | misratah
# Processing Record 3 of Set 9 | apac
# Processing Record 4 of Set 9 | plouzane
# Processing Record 5 of Set 9 | lakatoro
# Processing Record 6 of Set 9 | baykit
# Processing Record 7 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 9 | balyaga
# Processing Record 9 of Set 9 | minab
# Processing Record 10 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 9 | saint-pierre
# Processing Record 12 of Set 9 | khalkhal
# Processing Record 13 of Set 9 | pilar do sul
# Processing Record 14 of Set 9 | puerto colombia
# Processing Record 15 of Set 9 | camacha
# Processing Record 16 of Set 9 | lagoa
# Processing Record 17 of Set 9 | watsa
# Processing Record 18 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 9 | nong chik
# Processing Record 20 of Set 9 | areosa
# Processing Record 21 of Set 9 | maniitsoq
# Processing Record 22 of Set 9 | alekseyevka
# Processing Record 23 of Set 9 | mehamn
# Processing Record 24 of Set 9 | kodarma
# Processing Record 25 of Set 9 | grand-santi
# Processing Record 26 of Set 9 | ilulissat
# Processing Record 27 of Set 9 | minbu
# Processing Record 28 of Set 9 | camacupa
# Processing Record 29 of Set 9 | barahona
# Processing Record 30 of Set 9 | houma
# Processing Record 31 of Set 9 | little baguio
# Processing Record 32 of Set 9 | tecoanapa
# Processing Record 33 of Set 9 | xuanhua
# Processing Record 34 of Set 9 | bowen
# Processing Record 35 of Set 9 | barcelos
# Processing Record 36 of Set 9 | tokzar
# City not found. Skipping...
# Processing Record 37 of Set 9 | lewistown
# Processing Record 38 of Set 9 | quetigny
# Processing Record 39 of Set 9 | portland
# Processing Record 40 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 9 | los llanos de aridane
# Processing Record 43 of Set 9 | araguari
# Processing Record 44 of Set 9 | namtsy
# Processing Record 45 of Set 9 | la ronge
# Processing Record 46 of Set 9 | klaksvik
# Processing Record 47 of Set 9 | nabire
# Processing Record 48 of Set 9 | balaipungut
# Processing Record 49 of Set 9 | perry
# Processing Record 50 of Set 9 | ewa beach
# Processing Record 1 of Set 10 | palana
# Processing Record 2 of Set 10 | qaqortoq
# Processing Record 3 of Set 10 | champerico
# Processing Record 4 of Set 10 | hamilton
# Processing Record 5 of Set 10 | ampanihy
# Processing Record 6 of Set 10 | harper
# Processing Record 7 of Set 10 | semibratovo
# Processing Record 8 of Set 10 | vilyuysk
# Processing Record 9 of Set 10 | catia la mar
# Processing Record 10 of Set 10 | te anau
# Processing Record 11 of Set 10 | yarmouth
# Processing Record 12 of Set 10 | hirtshals
# Processing Record 13 of Set 10 | paramonga
# Processing Record 14 of Set 10 | bealanana
# Processing Record 15 of Set 10 | bonthe
# Processing Record 16 of Set 10 | bafoulabe
# Processing Record 17 of Set 10 | san cristobal
# Processing Record 18 of Set 10 | tautira
# Processing Record 19 of Set 10 | emerald
# Processing Record 20 of Set 10 | yar-sale
# Processing Record 21 of Set 10 | batetskiy
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | jinchang
# Processing Record 24 of Set 10 | margate
# Processing Record 25 of Set 10 | constitucion
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | bambanglipuro
# Processing Record 28 of Set 10 | papasquiaro
# City not found. Skipping...
# Processing Record 29 of Set 10 | cutervo
# Processing Record 30 of Set 10 | bom jardim
# Processing Record 31 of Set 10 | kalemie
# Processing Record 32 of Set 10 | mwinilunga
# Processing Record 33 of Set 10 | grajau
# Processing Record 34 of Set 10 | aklavik
# Processing Record 35 of Set 10 | kaka
# Processing Record 36 of Set 10 | yuci
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | vrangel
# Processing Record 39 of Set 10 | lumby
# Processing Record 40 of Set 10 | dangtu
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | gonaives
# Processing Record 43 of Set 10 | gimbi
# Processing Record 44 of Set 10 | krasnaya gora
# Processing Record 45 of Set 10 | karatau
# Processing Record 46 of Set 10 | finschhafen
# Processing Record 47 of Set 10 | andenes
# Processing Record 48 of Set 10 | ahipara
# Processing Record 49 of Set 10 | ciras
# City not found. Skipping...
# Processing Record 50 of Set 10 | denpasar
# Processing Record 1 of Set 11 | lukiv
# Processing Record 2 of Set 11 | bolekhiv
# Processing Record 3 of Set 11 | bonoua
# Processing Record 4 of Set 11 | galveston
# Processing Record 5 of Set 11 | piacabucu
# Processing Record 6 of Set 11 | aswan
# Processing Record 7 of Set 11 | port macquarie
# Processing Record 8 of Set 11 | imbituba
# Processing Record 9 of Set 11 | warri
# Processing Record 10 of Set 11 | kalachinsk
# Processing Record 11 of Set 11 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 12 of Set 11 | chapais
# Processing Record 13 of Set 11 | sambava
# Processing Record 14 of Set 11 | bud
# Processing Record 15 of Set 11 | elat
# Processing Record 16 of Set 11 | west bay
# Processing Record 17 of Set 11 | presidencia roque saenz pena
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | padang
# Processing Record 20 of Set 11 | natal
# Processing Record 21 of Set 11 | abaza
# Processing Record 22 of Set 11 | axim
# Processing Record 23 of Set 11 | acajutla
# Processing Record 24 of Set 11 | rawson
# Processing Record 25 of Set 11 | cayenne
# Processing Record 26 of Set 11 | viedma
# Processing Record 27 of Set 11 | isla vista
# Processing Record 28 of Set 11 | roma
# Processing Record 29 of Set 11 | yaan
# Processing Record 30 of Set 11 | fort abbas
# Processing Record 31 of Set 11 | vzmorye
# Processing Record 32 of Set 11 | taltal
# Processing Record 33 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 11 | bontang
# Processing Record 35 of Set 11 | pauini
# Processing Record 36 of Set 11 | maceio
# Processing Record 37 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 11 | talakan
# Processing Record 39 of Set 11 | agogo
# Processing Record 40 of Set 11 | the valley
# Processing Record 41 of Set 11 | san policarpo
# Processing Record 42 of Set 11 | kiama
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 11 | port-cartier
# Processing Record 47 of Set 11 | anamur
# Processing Record 48 of Set 11 | ihosy
# Processing Record 49 of Set 11 | phalombe
# Processing Record 50 of Set 11 | nelson bay
# Processing Record 1 of Set 12 | atar
# Processing Record 2 of Set 12 | doha
# Processing Record 3 of Set 12 | beyneu
# Processing Record 4 of Set 12 | leh
# Processing Record 5 of Set 12 | shenjiamen
# Processing Record 6 of Set 12 | millinocket
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | larap
# Processing Record 9 of Set 12 | klisura
# Processing Record 10 of Set 12 | kaiyuan
# Processing Record 11 of Set 12 | alyangula
# Processing Record 12 of Set 12 | hazorasp
# Processing Record 13 of Set 12 | bombay
# Processing Record 14 of Set 12 | candolim
# Processing Record 15 of Set 12 | novaya zaimka
# Processing Record 16 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 12 | vyshkov
# Processing Record 18 of Set 12 | buala
# Processing Record 19 of Set 12 | lensk
# Processing Record 20 of Set 12 | cartagena
# Processing Record 21 of Set 12 | korampallam
# Processing Record 22 of Set 12 | cap malheureux
# Processing Record 23 of Set 12 | padre bernardo
# Processing Record 24 of Set 12 | vestmanna
# Processing Record 25 of Set 12 | labuhan
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | abha
# Processing Record 28 of Set 12 | inhambane
# Processing Record 29 of Set 12 | novomalorossiyskaya
# Processing Record 30 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 31 of Set 12 | guaranesia
# Processing Record 32 of Set 12 | olinda
# Processing Record 33 of Set 12 | luganville
# Processing Record 34 of Set 12 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 35 of Set 12 | todos santos
# Processing Record 36 of Set 12 | yantal
# Processing Record 37 of Set 12 | tazovskiy
# Processing Record 38 of Set 12 | qui nhon
# Processing Record 39 of Set 12 | sao joao da barra
# Processing Record 40 of Set 12 | mayya
# Processing Record 41 of Set 12 | aseri
# Processing Record 42 of Set 12 | santander
# Processing Record 43 of Set 12 | severomuysk
# Processing Record 44 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 12 | nileshwar
# Processing Record 46 of Set 12 | tkibuli
# Processing Record 47 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 12 | camana
# Processing Record 49 of Set 12 | zabaykalsk
# Processing Record 50 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 13 | avera
# Processing Record 2 of Set 13 | mangaratiba
# Processing Record 3 of Set 13 | yulara
# Processing Record 4 of Set 13 | challapata
# Processing Record 5 of Set 13 | manyana
# Processing Record 6 of Set 13 | shache
# Processing Record 7 of Set 13 | fort nelson
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | cervignano del friuli
# Processing Record 10 of Set 13 | konstantinovka
# Processing Record 11 of Set 13 | talaya
# Processing Record 12 of Set 13 | orgun
# City not found. Skipping...
# Processing Record 13 of Set 13 | acarau
# Processing Record 14 of Set 13 | bonfim
# Processing Record 15 of Set 13 | salaberry-de-valleyfield
# Processing Record 16 of Set 13 | cherdyn
# Processing Record 17 of Set 13 | cotonou
# Processing Record 18 of Set 13 | fairbanks
# Processing Record 19 of Set 13 | arman
# Processing Record 20 of Set 13 | igrim
# Processing Record 21 of Set 13 | hit
# Processing Record 22 of Set 13 | kigorobya
# Processing Record 23 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 13 | shakiso
# Processing Record 25 of Set 13 | burhar
# Processing Record 26 of Set 13 | andra
# Processing Record 27 of Set 13 | gomel
# Processing Record 28 of Set 13 | labrea
# Processing Record 29 of Set 13 | kindu
# Processing Record 30 of Set 13 | bandar-e lengeh
# Processing Record 31 of Set 13 | la crosse
# Processing Record 32 of Set 13 | santa rosa
# Processing Record 33 of Set 13 | challans
# Processing Record 34 of Set 13 | camocim
# Processing Record 35 of Set 13 | monrovia
# Processing Record 36 of Set 13 | lingyuan
# Processing Record 37 of Set 13 | svarstad
# Processing Record 38 of Set 13 | moron
# Processing Record 39 of Set 13 | luderitz
# Processing Record 40 of Set 13 | cassilandia
# Processing Record 41 of Set 13 | ossora
# Processing Record 42 of Set 13 | nanortalik
# Processing Record 43 of Set 13 | marsa matruh
# Processing Record 44 of Set 13 | fukue
# Processing Record 45 of Set 13 | guanica
# Processing Record 46 of Set 13 | yinchuan
# Processing Record 47 of Set 13 | spirit river
# Processing Record 48 of Set 13 | grootfontein
# Processing Record 49 of Set 13 | batagay-alyta
# Processing Record 50 of Set 13 | barabash
# Processing Record 1 of Set 14 | lenine
# Processing Record 2 of Set 14 | port blair
# Processing Record 3 of Set 14 | kirakira
# Processing Record 4 of Set 14 | bloemfontein
# Processing Record 5 of Set 14 | barguzin
# Processing Record 6 of Set 14 | cockburn town
# Processing Record 7 of Set 14 | tamandare
# Processing Record 8 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 9 of Set 14 | pandan
# Processing Record 10 of Set 14 | bumba
# Processing Record 11 of Set 14 | havre
# Processing Record 12 of Set 14 | namikupa
# Processing Record 13 of Set 14 | bongandanga
# Processing Record 14 of Set 14 | havre-saint-pierre
# Processing Record 15 of Set 14 | nouadhibou
# Processing Record 16 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 14 | nara
# Processing Record 18 of Set 14 | terrace
# Processing Record 19 of Set 14 | santiago
# Processing Record 20 of Set 14 | fukuma
# Processing Record 21 of Set 14 | dingle
# Processing Record 22 of Set 14 | barsovo
# Processing Record 23 of Set 14 | tawzar
# City not found. Skipping...
# Processing Record 24 of Set 14 | borogontsy
# Processing Record 25 of Set 14 | havoysund
# Processing Record 26 of Set 14 | palmdale
# Processing Record 27 of Set 14 | sao raimundo nonato
# Processing Record 28 of Set 14 | nhulunbuy
# Processing Record 29 of Set 14 | unye
# City not found. Skipping...
# Processing Record 30 of Set 14 | coahuayana
# Processing Record 31 of Set 14 | berlevag
# Processing Record 32 of Set 14 | vina del mar
# Processing Record 33 of Set 14 | okha
# Processing Record 34 of Set 14 | juba
# Processing Record 35 of Set 14 | huarmey
# Processing Record 36 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 37 of Set 14 | otradnoye
# Processing Record 38 of Set 14 | liepaja
# Processing Record 39 of Set 14 | mount gambier
# Processing Record 40 of Set 14 | puerto princesa
# Processing Record 41 of Set 14 | golden rock
# City not found. Skipping...
# Processing Record 42 of Set 14 | puerto asis
# Processing Record 43 of Set 14 | palasa
# Processing Record 44 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 45 of Set 14 | oltina
# Processing Record 46 of Set 14 | hvolsvollur
# Processing Record 47 of Set 14 | kerouane
# Processing Record 48 of Set 14 | muros
# Processing Record 49 of Set 14 | cozumel
# Processing Record 50 of Set 14 | patea
# Processing Record 1 of Set 15 | bedesa
# Processing Record 2 of Set 15 | weihe
# Processing Record 3 of Set 15 | pochutla
# Processing Record 4 of Set 15 | snasa
# Processing Record 5 of Set 15 | ola
# Processing Record 6 of Set 15 | borzya
# Processing Record 7 of Set 15 | shelkovskaya
# Processing Record 8 of Set 15 | ferkessedougou
# Processing Record 9 of Set 15 | angoram
# Processing Record 10 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 15 | tabou
# Processing Record 12 of Set 15 | weligama
# Processing Record 13 of Set 15 | pachino
# Processing Record 14 of Set 15 | san francisco
# Processing Record 15 of Set 15 | egvekinot
# Processing Record 16 of Set 15 | henties bay
# Processing Record 17 of Set 15 | progreso
# Processing Record 18 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 15 | monroe
# Processing Record 20 of Set 15 | diffa
# Processing Record 21 of Set 15 | herat
# Processing Record 22 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 23 of Set 15 | taoudenni
# Processing Record 24 of Set 15 | pindiga
# Processing Record 25 of Set 15 | riyadh
# Processing Record 26 of Set 15 | okhotsk
# Processing Record 27 of Set 15 | pimentel
# Processing Record 28 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 29 of Set 15 | karakol
# Processing Record 30 of Set 15 | jacobina
# Processing Record 31 of Set 15 | nhamunda
# Processing Record 32 of Set 15 | havelock
# Processing Record 33 of Set 15 | lorengau
# Processing Record 34 of Set 15 | lodja
# Processing Record 35 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 15 | komsomolskiy
# Processing Record 37 of Set 15 | namwala
# Processing Record 38 of Set 15 | igunga
# Processing Record 39 of Set 15 | pavda
# City not found. Skipping...
# Processing Record 40 of Set 15 | tiznit
# Processing Record 41 of Set 15 | xinqing
# Processing Record 42 of Set 15 | saint simons
# Processing Record 43 of Set 15 | nashville
# Processing Record 44 of Set 15 | les cayes
# Processing Record 45 of Set 15 | richards bay
# Processing Record 46 of Set 15 | zeya
# Processing Record 47 of Set 15 | usinsk
# Processing Record 48 of Set 15 | gillette
# Processing Record 49 of Set 15 | matara
# Processing Record 50 of Set 15 | shu
# Processing Record 1 of Set 16 | arawa
# Processing Record 2 of Set 16 | srednekolymsk
# Processing Record 3 of Set 16 | kiunga
# Processing Record 4 of Set 16 | kapit
# Processing Record 5 of Set 16 | saint-augustin
# Processing Record 6 of Set 16 | moussoro
# Processing Record 7 of Set 16 | graham
# Processing Record 8 of Set 16 | karpogory
# Processing Record 9 of Set 16 | takoradi
# Processing Record 10 of Set 16 | wa
# City not found. Skipping...
# Processing Record 11 of Set 16 | qasigiannguit
# Processing Record 12 of Set 16 | igarka
# Processing Record 13 of Set 16 | san lawrenz
# Processing Record 14 of Set 16 | la libertad
# Processing Record 15 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 16 of Set 16 | sangar
# Processing Record 17 of Set 16 | bairiki
# Processing Record 18 of Set 16 | pafos
# Processing Record 19 of Set 16 | drumheller
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Rikitea      PF -23.1203 -134.9692     73.94        80         100
# 1       Kapaa      US  22.0752 -159.3190     82.38        74          90
# 2        Hilo      US  19.7297 -155.0900     80.33        69          20
# 3     Waipawa      NZ -41.4122  175.5153     53.46        68           0
# 4       Airai      TL  -8.9266  125.4092     56.84        83          34
# 5      Atuona      PF  -9.8000 -139.0333     77.49        78          52
# 6       Birin      NP  26.8865   88.0718     62.56        85          12
# 7  Butaritari      KI   3.0707  172.7902     83.61        74          13
# 8   Hithadhoo      MV  -0.6000   73.0833     82.47        69         100
# 9       Rocha      UY -34.4833  -54.3333     58.46        85          60
#
#    Wind Speed Current Description
# 0       22.59     overcast clouds
# 1        4.00     overcast clouds
# 2        4.61          few clouds
# 3       14.83           clear sky
# 4        1.77    scattered clouds
# 5       18.14       broken clouds
# 6        4.83          few clouds
# 7       14.07          few clouds
# 8       14.61     overcast clouds
# 9       11.32       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.v
city_data_df.to_csv(output_data_file, index_label="City_ID")
